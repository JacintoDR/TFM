# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
results = pd.read_csv('gan_loss_abalone.csv')
results.columns
# Out:
# Index(['Epoch', 'Discriminator', 'Generator'], dtype='object')

# %%
results
# Out:
#      Epoch  Discriminator  Generator
# 0        1          0.523      0.831
# 1        2          0.518      0.846
# 2        3          0.512      0.877
# 3        4          0.497      0.848
# 4        5          0.505      0.863
# ..     ...            ...        ...
# 195    196          0.323      1.656
# 196    197          0.322      1.707
# 197    198          0.332      1.747
# 198    199          0.327      1.657
# 199    200          0.334      1.682
#
# [200 rows x 3 columns]

# %%
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Curvas entrenamiento GAN')

for c in results.columns:
    if c != 'Epoch':
        plt.plot(results['Epoch'], results[c])

plt.ylim(0, 2.3)
plt.legend(results.columns[1:], loc=1)
plt.savefig('plot_gan_losses1.svg')
plt.show()
plt.close()

# %%
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Curvas entrenamiento GAN')

plt.plot(results['Epoch'], results['Discriminator'], 'b--')
plt.plot(results['Epoch'], results['Generator'], 'g-')

plt.ylim(0, 2.3)
plt.legend(results.columns[1:], loc=1)
plt.savefig('plot_gan_losses2.svg')
plt.show()
plt.close()
